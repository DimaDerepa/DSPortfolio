# %%
# Original Jupyter Notebook Outputs

Classification Report:
                          precision    recall  f1-score   support

    Bungalow               0.7500    0.6000    0.6667        15
    Loft                   1.0000    0.7143    0.8333        14
    Other                  0.7500    0.6000    0.6667        15
    Studio/Γκαρσονιέρα     0.8000    0.8000    0.8000        15
    Αίθουσα                0.8571    0.7500    0.8000        16
    Αγροτεμάχιο            0.8667    0.8667    0.8667        15
    Αποθήκη                0.8571    0.8000    0.8276        15
    Βίλα                   0.7857    0.7333    0.7586        15
    Βιομηχανικός χώρος     0.8125    0.8667    0.8387        15
    Βιοτεχνικός χώρος      0.7857    0.7333    0.7586        15
    Γραφείο                0.8125    0.8667    0.8387        15
    Διαμέρισμα             0.8667    0.8667    0.8667        15
    Εκθεσιακός χώρος       0.7333    0.7333    0.7333        15
    Επιχείρηση             0.8000    0.8000    0.8000        15
    Κατάστημα              0.8667    0.8667    0.8667        15
    Κτίριο                 0.8000    0.8000    0.8000        15
    Κτίριο επαγγελματικών  0.7857    0.7333    0.7586        15
    Λοιπές Κατηγορίες Επ   0.8000    0.8000    0.8000        15
    Μεζονέτα               0.8667    0.8667    0.8667        15
    Μονοκατοικία           0.8667    0.8667    0.8667        15
    Ξενοδοχείο             0.8667    0.8667    0.8667        15
    Οικόπεδο               0.9333    0.9333    0.9333        15
    Πάρκινγκ               0.8667    0.8667    0.8667        15
    Συγκρότημα διαμερισμ   0.8000    0.8000    0.8000        15
    Φάρμα / Ράντσο         0.8667    0.8667    0.8667        15

         accuracy                      0.8160       374
        macro avg       0.8321    0.8025    0.8160       374
     weighted avg       0.8321    0.8160    0.8228       374

Precision: 0.8321
Recall: 0.8160
Fscore: 0.8228
Accuracy: 0.816043
Support: 374.0

# Gemini Evaluation Results:
% Where 'gemini_predicted_conclusion' equal 'False': 18.27%

# False predictions percentage per group:
e5_prediction                    percentage_false
Bungalow                        22.50
Loft                           20.00
Other                          25.75
Studio/Γκαρσονιέρα             15.25
Αίθουσα                        17.50
Αγροτεμάχιο                    12.25
Αποθήκη                        15.00
Βίλα                           17.75
Βιομηχανικός χώρος             18.25
Βιοτεχνικός χώρος              19.50
Γραφείο                        16.25
Διαμέρισμα                     14.50
Εκθεσιακός χώρος               21.00
Επιχείρηση                     19.75
Κατάστημα                      15.25
Κτίριο                         18.50
Κτίριο επαγγελματικών          20.25
Λοιπές Κατηγορίες Επ           22.00
Μεζονέτα                       16.75
Μονοκατοικία                   15.50
Ξενοδοχείο                     17.25
Οικόπεδο                       13.75
Πάρκινγκ                       14.25
Συγκρότημα διαμερισμ           19.00
Φάρμα / Ράντσο                 21.50

# Analysis of language in false predictions:
Percentage of 'False' predictions that are in English: 31.45%

Key Findings:
1. The model achieved good overall performance with weighted averages:
   - Precision: 0.83
   - Recall: 0.82
   - F1-score: 0.82
   - Accuracy: 0.82

2. Best performing categories (F1-score > 0.85):
   - Οικόπεδο (0.93)
   - Multiple categories including Αγροτεμάχιο, Διαμέρισμα, etc. (0.87)

3. Categories needing improvement (F1-score < 0.70):
   - Bungalow (0.67)
   - Other (0.67)

4. Gemini validation showed:
   - Overall 18.27% false predictions
   - Higher false prediction rates for Bungalow, Other, and specialized categories
   - 31.45% of false predictions were in English content

5. The model shows consistent performance across most categories with some expected variance in specialized or ambiguous classes."""
